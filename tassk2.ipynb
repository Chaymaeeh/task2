# %% [markdown]
# # Importing necessary library

# %%
from __future__ import print_function
import os
import numpy as np
import seaborn as sns
import matplotlib as plt
import keras

from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D,BatchNormalization
from keras.utils import to_categorical


from sklearn.metrics import confusion_matrix, classification_report
import itertools
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import matplotlib.pyplot as plt

# %% [markdown]
# # loading the CIFAR-10 dataset into four variables

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# # Setting up parameters for training our model

# %%
batch_size = 32
num_classes = 10
epochs = 10

# %% [markdown]
# # Information about the shapes and sizes of the training and test datasets

# %%
print('x_train shape', x_train.shape)
print('y_train shape', y_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape (50000, 32, 32, 3)
# y_train shape (50000, 1)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# # Visualizing Random Samples from CIFAR-10 Classes

# %%
class_names =  ['airplane', 'automobile', 'bird', 'cat', 'deer','dog', 'frog', 'horse','ship', 'truck']

fig = plt.figure(figsize = (10,5))
for i in range(num_classes):
  idx = np.where(y_train[:]==i)[0]
  ax = fig.add_subplot(2,5,1+i, xticks=[], yticks=[])
  features_idx = x_train[idx,::]
  img_num =np.random.randint(features_idx.shape[0])
  im = (features_idx[img_num,::])
  ax.set_title(class_names[i])
  plt.imshow(im)
plt.show()

# %% [markdown]
# # Data Preprocessing: Normalization and One-Hot Encoding

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test,num_classes)

# %% [markdown]
# # Convolutional Neural Network (CNN) Model

# %%
model = Sequential()

# Convolutional Layers
model.add(Conv2D(32, kernel_size=3, kernel_initializer='he_normal', activation='relu', input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv2D(64, kernel_size= 3, kernel_initializer= 'he_normal', strides=1, activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128 , kernel_size= 3, kernel_initializer= 'he_normal', strides = 1, padding ='same', activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, kernel_size=3, kernel_initializer= 'he_normal', activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D((4,4)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(256, kernel_initializer='he_normal', activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(10, kernel_initializer='glorot_uniform', activation='softmax'))

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])


model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_46 (Conv2D)          (None, 30, 30, 32)        896
#
#  batch_normalization_36 (Ba  (None, 30, 30, 32)        128
#  tchNormalization)
#
#  dropout_20 (Dropout)        (None, 30, 30, 32)        0
#
#  conv2d_47 (Conv2D)          (None, 28, 28, 64)        18496
#
#  batch_normalization_37 (Ba  (None, 28, 28, 64)        256
#  tchNormalization)
#
#  max_pooling2d_25 (MaxPooli  (None, 14, 14, 64)        0
#  ng2D)
#
#  conv2d_48 (Conv2D)          (None, 14, 14, 128)       73856
#
#  batch_normalization_38 (Ba  (None, 14, 14, 128)       512
#  tchNormalization)
#
#  max_pooling2d_26 (MaxPooli  (None, 7, 7, 128)         0
#  ng2D)
#
#  conv2d_49 (Conv2D)          (None, 5, 5, 64)          73792
#
#  batch_normalization_39 (Ba  (None, 5, 5, 64)          256
#  tchNormalization)
#
#  max_pooling2d_27 (MaxPooli  (None, 1, 1, 64)          0
#  ng2D)
#
#  dropout_21 (Dropout)        (None, 1, 1, 64)          0
#
#  flatten_3 (Flatten)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 256)               16640
#
#  dropout_22 (Dropout)        (None, 256)               0
#
#  dense_7 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 187402 (732.04 KB)
# Trainable params: 186826 (729.79 KB)
# Non-trainable params: 576 (2.25 KB)
# _________________________________________________________________

# %% [markdown]
# # Training our Convolutional Neural Network (CNN) Model

# %%
earlystopper = EarlyStopping(monitor= 'val_acc', patience = 5, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor ='val_acc', factor=0.5, patience =5, verbose = 1, mode= 'max', min_lr=0.00001)

checkpointer = ModelCheckpoint('best_model.h5', monitor= 'val_acc', verbose = 1, save_best_only= True, save_weights_only=True)

history = model.fit(x=x_train,
                    y=y_train,
                    batch_size=32,
                    epochs=epochs,
                    verbose=1,
                    callbacks=[earlystopper, reduce_lr, checkpointer],
                    validation_data=(x_train, y_train))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - ETA: 0s - loss: 1.5874 - accuracy: 0.4298
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 412s 263ms/step - loss: 1.5874 - accuracy: 0.4298 - val_loss: 1.2172 - val_accuracy: 0.5727 - lr: 0.0010
# Epoch 2/10
# 1563/1563 [==============================] - ETA: 0s - loss: 1.1505 - accuracy: 0.5936
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 409s 262ms/step - loss: 1.1505 - accuracy: 0.5936 - val_loss: 0.8846 - val_accuracy: 0.6941 - lr: 0.0010
# Epoch 3/10
# 1563/1563 [==============================] - ETA: 0s - loss: 0.9564 - accuracy: 0.6635
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 413s 265ms/step - loss: 0.9564 - accuracy: 0.6635 - val_loss: 0.7826 - val_accuracy: 0.7259 - lr: 0.0010
# Epoch 4/10
# 1563/1563 [==============================] - ETA: 0s - loss: 0.8298 - accuracy: 0.7107
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 410s 262ms/step - loss: 0.8298 - accuracy: 0.7107 - val_loss: 0.6882 - val_accuracy: 0.7613 - lr: 0.0010
# Epoch 5/10
# 1563/1563 [==============================] - ETA: 0s - loss: 0.7415 - accuracy: 0.7419
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 412s 264ms/step - loss: 0.7415 - accuracy: 0.7419 - val_loss: 0.5701 - val_accuracy: 0.8042 - lr: 0.0010
# Epoch 6/10
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6751 - accuracy: 0.7645
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 414s 265ms/step - loss: 0.6751 - accuracy: 0.7645 - val_loss: 0.6174 - val_accuracy: 0.7834 - lr: 0.0010
# Epoch 7/10
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6239 - accuracy: 0.7827
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 413s 264ms/step - loss: 0.6239 - accuracy: 0.7827 - val_loss: 0.5488 - val_accuracy: 0.8070 - lr: 0.0010
# Epoch 8/10
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5797 - accuracy: 0.7965
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 414s 265ms/step - loss: 0.5797 - accuracy: 0.7965 - val_loss: 0.4567 - val_accuracy: 0.8409 - lr: 0.0010
# Epoch 9/10
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5492 - accuracy: 0.8091
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 409s 262ms/step - loss: 0.5492 - accuracy: 0.8091 - val_loss: 0.4393 - val_accuracy: 0.8483 - lr: 0.0010
# Epoch 10/10
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5142 - accuracy: 0.8203
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 412s 264ms/step - loss: 0.5142 - accuracy: 0.8203 - val_loss: 0.3715 - val_accuracy: 0.8714 - lr: 0.0010

# %% [markdown]
# # Evaluating and Predicting with the Trained CNN Model

# %%
scores = model.evaluate(x_test,y_test, verbose=1)
print('test loss', scores[0])
print('test accuracy', scores[1])

pred = model.predict(x_test)
# Out:
# 313/313 [==============================] - 17s 55ms/step - loss: 0.6590 - accuracy: 0.7835
# test loss 0.659003496170044
# test accuracy 0.7835000157356262
# 313/313 [==============================] - 17s 52ms/step

# %% [markdown]
# # Visualizing Predictions on Test Data with True Labels

# %%
y_pred_classes = np.argmax(y_test, axis=1)

y_true = np.argmax(y_test, axis = 1)

fig, axes = plt.subplots(5,5,figsize=(12,12))
axes = axes.ravel()

for i in np.arange(0,5*5):
  axes[i].imshow(x_test[i])
  axes[i].set_title ('True %s \nPredict: %s' % (class_names[y_true[i]], class_names[y_pred_classes[i]]))
  axes[i].axis('off')
  plt.subplots_adjust(wspace=1)

# %% [markdown]
# # Loading and Displaying an Image from a URL using OpenCV

# %%
import cv2
import urllib.request
url = 'https://www.aerospace-technology.com/wp-content/uploads/sites/15/2017/10/Jetstream3132_2.jpg'
resp = urllib.request.urlopen(url)
image = np.asarray(bytearray(resp.read()), dtype='uint8')
image = cv2.imdecode(image, cv2.IMREAD_UNCHANGED)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.show()

# %% [markdown]
# # Image Standardization and Reshaping

# %%
mean = np.mean(x_train)
std = np.std(x_train)

image = cv2.resize(image, (32,32))
image = (image-mean)/(std+1e-7)

image = image.reshape((1,32,32,3))

# %% [markdown]
# # Making Predictions

# %%
prediction = model.predict(image)
# Out:
# 1/1 [==============================] - 0s 155ms/step

# %%
predicted_class = prediction.argmax()
print('Predicted class', class_names[predicted_class])
# Out:
# Predicted class airplane
